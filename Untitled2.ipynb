# %% [markdown]
# # List Lots of Files

# %%
import os

# %%
def collect_file_names(input_folder,  pattern):
    """
    Collects the input_currency data set file names
    :param input_folder, folder from which to collect the files
    :param pattern: Search pattern

    :return  _input_files: Input file list
    """
    _dir_list = next(os.walk(input_folder))[2]
    _input_files = [s for s in _dir_list if pattern in s]
    return _input_files

os.mkdir('./temp/')

for i in range(70000):
    with open(f'./temp/{i}.txt', 'w') as fp:
        fp.write(str(i))

_file_list = collect_file_names('./temp/', 'txt')

print('Files ', len(_file_list))
# Out:
# Files  70000

# %%
print(_file_list)
# Out:
# ['0.txt', '1.txt', '10.txt', '100.txt', '1000.txt', '10000.txt', '10001.txt', '10002.txt', '10003.txt', '10004.txt', '10005.txt', '10006.txt', '10007.txt', '10008.txt', '10009.txt', '1001.txt', '10010.txt', '10011.txt', '10012.txt', '10013.txt', '10014.txt', '10015.txt', '10016.txt', '10017.txt', '10018.txt', '10019.txt', '1002.txt', '10020.txt', '10021.txt', '10022.txt', '10023.txt', '10024.txt', '10025.txt', '10026.txt', '10027.txt', '10028.txt', '10029.txt', '1003.txt', '10030.txt', '10031.txt', '10032.txt', '10033.txt', '10034.txt', '10035.txt', '10036.txt', '10037.txt', '10038.txt', '10039.txt', '1004.txt', '10040.txt', '10041.txt', '10042.txt', '10043.txt', '10044.txt', '10045.txt', '10046.txt', '10047.txt', '10048.txt', '10049.txt', '1005.txt', '10050.txt', '10051.txt', '10052.txt', '10053.txt', '10054.txt', '10055.txt', '10056.txt', '10057.txt', '10058.txt', '10059.txt', '1006.txt', '10060.txt', '10061.txt', '10062.txt', '10063.txt', '10064.txt', '10065.txt', '10066.txt', '10
# ...

# %%
for w in os.walk('.'):
    print(w, '\n')
# Out:
# ('.', ['.ipynb_checkpoints'], ['JUPYTER.bat', 'pandas merge with left option losing rows.ipynb', 'Pivot table.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb'])
#
# ('.\\.ipynb_checkpoints', [], ['pandas merge with left option losing rows-checkpoint.ipynb', 'Pivot table-checkpoint.ipynb', 'Untitled-checkpoint.ipynb', 'Untitled1-checkpoint.ipynb', 'Untitled2-checkpoint.ipynb'])

# %%
len(_list)
# Out:
# 2

# %%
_list[0]
# Out:
# ('.',
#  ['.ipynb_checkpoints'],
#  ['JUPYTER.bat',
#   'pandas merge with left option losing rows.ipynb',
#   'Pivot table.ipynb',
#   'Untitled.ipynb',
#   'Untitled1.ipynb',
#   'Untitled2.ipynb'])

# %%
import os

os.mkdir('./temp/')

for i in range(70000):
    with open(f'./temp/{i}.txt', 'w') as fp:
        fp.write(str(i))

with os.scandir('./temp/') as scandir_it:
    entries = list(scandir_it)

print(len(entries))
# Out:
# 70000
